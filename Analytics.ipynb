# %%
from pathlib import Path
import pandas as pd
import dask.dataframe as dd
from IPython.display import display
pd.options.display.max_columns = None

# %%
dataFolder = Path.cwd().joinpath('Data')

# %%
dataFolder
# Out:
# PosixPath('/mnt/New Volume/Projects/Challenges/zypmedia/Data')

# %%
columnHeaders = ['bidID', 'Timestamp', 'XYZID', 'useragent', 'ip', 'region', 'city', 'adexchange', 'domain', \
                 'url', 'anonURLID', 'adSlotID', 'width', 'height', \
                 'visibility', 'format', 'slotPrice', 'creativeId', 'bidprice', 'adverId', 'userTag']

# %%
biddataframes = [dd.read_csv(f, sep='\t', names=columnHeaders, blocksize=None, compression='bz2') \
                 for f in dataFolder.glob("bid*.bz2")]

# %%
biddf = dd.concat(biddataframes, axis=0)
biddf.head()
# Out:
#                               bidID          Timestamp        XYZID  \
# 0  35fd1ad90bf35fadd3047b0bfc7be326  20131019100000067  DAB8cXDkxdy
# 1  79b665070e59ebb2b07a7592334ce75a  20131019100000039  D96MEd7Dxp9
# 2  633707a960a18e07fc639afa6a4afd97  20131019100000062          NaN
# 3  264b38e31c1d6978802292a7815c8b80  20131019100000768  DAIJrqA8xbC
# 4  55c2625f4872a9246fde4b719067424b  20131019100002089          NaN
#
#                                            useragent             ip  region  \
# 0  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...  113.107.229.*     216
# 1  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.1...    119.32.95.*     216
# 2  Mozilla/4.0 (Windows; U; Windows NT 5.1; zh-TW...   113.83.245.*     216
# 3  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...   113.111.33.*     216
# 4  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...     183.1.70.*     216
#
#    city  adexchange                            domain  \
# 0   237           1  b5f57062ae7f4ba7f1489b9133b991d6
# 1   217           2  ed5dfe7e38655bf6defecf2f284e79ba
# 2   227           2  f78321209a9738b2e198ddc508045c99
# 3   217           3  369fbd5dd0636d8b3e8199bf027854b1
# 4   217           3  eb6cf22883534275b3c9b6af2307e28d
#
#                                 url   ...                         adSlotID  \
# 0  51773ab0ae291eb88b2740e781a99099   ...     mm_30646014_3428401_13076720
# 1  11f05bd65774f9b52400e73e76dde41b   ...                       1058395156
# 2                               NaN   ...                        221332875
# 3  6bf50b173a5827b99f9ddde1056ee59a   ...              discuz_18316225_006
# 4  25561276d5e8edaec04853fb455c0504   ...                    Game_F_Width1
#
#   width  height  visibility format slotPrice  creativeId  bidprice  adverId  \
# 0   300     250          Na  Fixed         0        7323       294     2259
# 1   250     250   OtherView     Na         4        7321       277     2259
# 2   300     250   OtherView     Na         5        7323       277     2259
# 3   728      90          Na     Na        20        7330       294     2259
# 4  1000      90          Na     Na        50        7336       294     2259
#
#    userTag
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 21 columns]

# %%
columnHeaders = ['bidID', 'Timestamp', 'logType', 'XYZID', 'useragent', 'ip', 'region', 'city', 'adexchange', 'domain', \
                 'url', 'anonURLID', 'adSlotID', 'width', 'height', \
                 'visibility', 'format', 'slotPrice', 'creativeId', 'bidprice', 'payPrice', 'keypageUrl', 'adverId', 'userTag']

# %%
clkdataframes = [pd.read_csv(f, sep='\t', names=columnHeaders, compression='bz2') \
                 for f in dataFolder.glob("clk*.bz2")]

# %%
clkdf = pd.concat(clkdataframes, axis=0)
clkdf.head()
# Out:
#                               bidID          Timestamp  logType        XYZID  \
# 0  c671f4c2919831696be3efa912ca1bd5  20131024175602152        2  DAOETC97vz2
# 1  44f58336fb0dbeaf7f0b2be1b7c6dc45  20131024181101117        2  DAOIB11rvfj
# 2  c002cddb8118d4f5683a16c74b5d6a24  20131024170802729        2  DAOH82BPz61
# 3  8b52831079abbaf317c53cf6eb15d524  20131024143700840        2  DAOEZ0AMs9x
# 4  8cb74b8c3242e651e44825d2307de7c6  20131024173001601        2  DAOHU19Pxav
#
#                                            useragent             ip  region  \
# 0  Mozilla/5.0 (Linux; U; Android 2.3.6; zh-cn; O...   117.136.24.*     201
# 1  Mozilla/5.0 (Linux; U; Android 2.3.4; zh-cn; A...  123.151.186.*       2
# 2  Mozilla/5.0 (Linux; U; Android 4.1.2; zh-cn; S...   115.218.67.*      94
# 3  Mozilla/5.0 (Linux; U; Android 4.1.2; zh-cn; G...   113.94.124.*     216
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 6_0_2 like ...  180.106.148.*      80
#
#    city  adexchange                            domain  \
# 0   202         NaN                               NaN
# 1     2         NaN                               NaN
# 2    97         NaN                               NaN
# 3   225         NaN                               NaN
# 4    85         1.0  a5f6c3952b9b24fa5c6cc608aa1625a2
#
#                                 url  anonURLID                      adSlotID  \
# 0                               NaN        NaN                             1
# 1                               NaN        NaN                             1
# 2                               NaN        NaN                             1
# 3                               NaN        NaN                             1
# 4  e70ee1d3859dda68a4cd992bb9035243        NaN  mm_14442304_3436307_13298998
#
#    width  height visibility format  slotPrice  creativeId  bidprice  payPrice  \
# 0    320      50  FirstView     Na          6       11908       277         6
# 1    320      50  FirstView     Na        131       11908       277       131
# 2    320      50  FirstView     Na          6       11908       277        28
# 3    320      50  FirstView     Na        170       11908       277       170
# 4    640      90         Na     Na          0       12626       294        12
#
#    keypageUrl  adverId  userTag
# 0         NaN     2997      NaN
# 1         NaN     2997      NaN
# 2         NaN     2997      NaN
# 3         NaN     2997      NaN
# 4         NaN     2261      NaN

# %%
convdataframes = [pd.read_csv(f, sep='\t', names=columnHeaders, compression='bz2') \
                 for f in dataFolder.glob("conv*.bz2")]
convdf = pd.concat(convdataframes, axis=0)
convdf.head()
# Out:
#                               bidID          Timestamp  logType        XYZID  \
# 0  8d7fa5a491ec520c36a046db4cd4061c  20131019171702253        3  DADLdKELxuH
# 1  81527f78a3ea223f97482c95b4c501da  20131019122616880        3  D6GANZ4f2ao
# 2  db1fd2b40dd0df95c3f475a4b2c312fe  20131019125303533        3  DAJ9wV2ZuY3
# 3  b17a4306dc03349c57095146fc93371c  20131019162701673        3  DAGLVfCKw~N
# 4  ce889bcc0509a1e877d8256c8d5246b0  20131019060705738        3  DAJ675BYua2
#
#                                            useragent             ip  region  \
# 0  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...     58.61.88.*     216
# 1  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...   14.156.126.*     216
# 2  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.1...  113.111.204.*     216
# 3  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.1...    112.97.36.*     216
# 4  Mozilla/4.0 (compatible; MSIE 7.0; Windows NT ...   120.83.165.*     216
#
#    city  adexchange                            domain  \
# 0   219           3  dd4270481b753dde29898e27c7c03920
# 1   233           3  7ed515fe566938ee6cfbb6ebb7ea4995
# 2   217           2  926bd462dcbf9b9e6ea2d03fb0e82f4e
# 3   219           2  28a3e7ac0d8c92058913d160ee1520b5
# 4   222           3  7f24b61d84ebf998424e78786b477182
#
#                                 url  anonURLID             adSlotID  width  \
# 0  3a4410523c0db36c62799b96a144dd06        NaN    ALLINONE_F_Width1   1000
# 1  b958097854df967c5104075a29de36c9        NaN    ALLINONE_F_Width1   1000
# 2  16c42b6bbdb6b9de83ebb094d313a8c1        NaN           4176125399    336
# 3  ddb9b92a6da69428b3a88d3aaf12d181        NaN           1826232311    200
# 4  ef58953c18a42061dc5dd8d2ceec3910        NaN  discuz_18787367_001    960
#
#    height visibility format  slotPrice  creativeId  bidprice  payPrice  \
# 0      90         Na     Na         70        7336       294       288
# 1      90         Na     Na         70        7336       294        70
# 2     280  OtherView     Na        237        7326       277       237
# 3     200  OtherView     Na          5        7319       277        17
# 4      90         Na     Na         20        7335       294        20
#
#    keypageUrl  adverId  userTag
# 0         NaN     2259      NaN
# 1         NaN     2259      NaN
# 2         NaN     2259      NaN
# 3         NaN     2259      NaN
# 4         NaN     2259      NaN

# %%
convdf.logType.unique()
# Out:
# array([3])
